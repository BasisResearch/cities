# %%
import os

import dill

import matplotlib.pyplot as plt
import torch
import pyro
import copy

import torch
import pyro
import pyro.distributions as dist
import matplotlib.pyplot as plt
import numpy as np

import torch
import time

import pandas as pd
from torch.utils.data import DataLoader

from chirho.indexed.ops import IndexSet, gather
import seaborn as sns


import pyro
from pyro.infer import Predictive

from chirho.counterfactual.handlers import MultiWorldCounterfactual

# from cities.modeling.zoning_models.units_causal_model import UnitsCausalModel
#from cities.modeling.zoning_models.distance_causal_model import DistanceCausalModel
from cities.modeling.zoning_models.tracts_model import TractsModel, TractsModelNoRatios
from cities.modeling.svi_inference import run_svi_inference
from cities.utils.data_loader import select_from_data


from pyro.infer.autoguide import AutoDiagonalNormal, AutoMultivariateNormal, init_to_mean

from cities.modeling.evaluation import (
    prep_data_for_test,
    test_performance,
)

from cities.modeling.svi_inference import run_svi_inference
from pyro.infer import Predictive
from chirho.interventional.handlers import do


smoke_test = "CI" in os.environ

# use when testing model health
smoke_test = True

n_steps = 10 if smoke_test else 1500
num_samples = 10 if smoke_test else 1000

from cities.utils.data_grabber import find_repo_root

root = find_repo_root()

# %%
census_tracts_data_path = os.path.join(root, "data/minneapolis/processed/census_tracts_dataset.pt")


ct_dataset_read = torch.load(census_tracts_data_path)

ct_loader = DataLoader(
    ct_dataset_read, batch_size=len(ct_dataset_read), shuffle=True
)

data = next(iter(ct_loader))

print(data["continuous"].keys())
print(data['categorical'].keys())
# Out:
# dict_keys(['housing_units', 'housing_units_original', 'income', 'income_original', 'mean_distance', 'mean_distance_original', 'mean_limit', 'mean_limit_original', 'median_distance', 'median_distance_original', 'median_value', 'median_value_original', 'segregation', 'segregation_original', 'total_value', 'total_value_original', 'white', 'white_original'])
# dict_keys(['year'])

# %%
kwargs = {
    "categorical": [
        "year",
    ],
    "continuous": {
      'housing_units',
      'total_value',
      'median_value',
      'mean_limit',
      'median_distance',
      'income',
      'segregation',
      'white',
    },
    'outcome': 'housing_units'
}

subset = select_from_data(data, kwargs)
print(subset["continuous"].keys())
# Out:
# dict_keys(['housing_units', 'income', 'mean_limit', 'median_distance', 'median_value', 'segregation', 'total_value', 'white'])

# %%
tracts_model = TractsModelNoRatios(
    **subset, categorical_levels=ct_dataset_read.categorical_levels
)

with pyro.poutine.trace() as tr:
    tracts_model(**subset)

print(sorted(tr.trace.nodes.keys()))
# Out:
# ['bias_continuous_distance_housing_units', 'bias_continuous_distance_income', 'bias_continuous_distance_limit', 'bias_continuous_distance_median_value', 'bias_continuous_distance_segregation', 'bias_continuous_distance_white', 'bias_continuous_income_housing_units', 'bias_continuous_income_median_value', 'bias_continuous_limit_housing_units', 'bias_continuous_limit_median_value', 'bias_continuous_median_value_housing_units', 'bias_continuous_segregation_housing_units', 'bias_continuous_segregation_income', 'bias_continuous_segregation_median_value', 'bias_continuous_white_housing_units', 'bias_continuous_white_income', 'bias_continuous_white_median_value', 'bias_continuous_white_segregation', 'data', 'distance', 'housing_units', 'income', 'limit', 'mean_outcome_prediction_housing_units', 'mean_outcome_prediction_income', 'mean_outcome_prediction_limit', 'mean_outcome_prediction_median_value', 'mean_outcome_prediction_segregation', 'mean_outcome_prediction_white', 'median_value', 'seg
# ...

# %%
pyro.render_model(
    lambda: tracts_model(**subset),
    render_deterministic=True,
)
# Out:
# /home/rafal/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:628: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
pyro.clear_param_store()
from cities.modeling.evaluation import recode_categorical
import copy

train_loader, test_loader, categorical_levels = prep_data_for_test(
    census_tracts_data_path,
    train_size=0.6)


test_performance(
    tracts_model,
    kwargs,
    train_loader,
    test_loader,
    categorical_levels,
    outcome_type="continuous",
    outcome_name="housing_units",
    n_steps=2000,
    plot=True,
    is_class=False,
)
# Out:
# [iteration 0001] loss: 6335.2124
# [iteration 0050] loss: 5538.7417
# [iteration 0100] loss: 5429.1665
# [iteration 0150] loss: 5357.4409
# [iteration 0200] loss: 5320.5791
# [iteration 0250] loss: 5395.2998
# [iteration 0300] loss: 5319.1909
# [iteration 0350] loss: 5318.4248
# [iteration 0400] loss: 5323.3276
# [iteration 0450] loss: 5303.0225
# [iteration 0500] loss: 5343.4917
# [iteration 0550] loss: 5305.0327
# [iteration 0600] loss: 5312.6167
# [iteration 0650] loss: 5313.2905
# [iteration 0700] loss: 5302.0181
# [iteration 0750] loss: 5306.5166
# [iteration 0800] loss: 5338.5615
# [iteration 0850] loss: 5330.4741
# [iteration 0900] loss: 5326.5347
# [iteration 0950] loss: 5322.3691
# [iteration 1000] loss: 5316.4604
# [iteration 1050] loss: 5301.1855
# [iteration 1100] loss: 5308.1309
# [iteration 1150] loss: 5300.0264
# [iteration 1200] loss: 5329.4727
# [iteration 1250] loss: 5300.3145
# [iteration 1300] loss: 5299.8862
# [iteration 1350] loss: 5305.5420
# ...

# %%
pyro.clear_param_store()
guide = run_svi_inference(
    tracts_model, n_steps=2000, lr=0.03, **subset
)

predictive = Predictive(tracts_model, guide=guide, num_samples=1000)

subset_for_preds = copy.deepcopy(subset)
subset_for_preds['continuous']['housing_units'] = None  

preds = predictive(**subset_for_preds)
# Out:
# [iteration 0001] loss: 10738.1934
# [iteration 0050] loss: 9019.3311
# [iteration 0100] loss: 8836.6074
# [iteration 0150] loss: 8899.6533
# [iteration 0200] loss: 8751.2275
# [iteration 0250] loss: 8750.1084
# [iteration 0300] loss: 8745.0361
# [iteration 0350] loss: 8754.4404
# [iteration 0400] loss: 8740.0625
# [iteration 0450] loss: 8734.9512
# [iteration 0500] loss: 8746.8047
# [iteration 0550] loss: 8799.6445
# [iteration 0600] loss: 8747.8428
# [iteration 0650] loss: 8781.0195
# [iteration 0700] loss: 8806.1182
# [iteration 0750] loss: 8774.6777
# [iteration 0800] loss: 8772.9609
# [iteration 0850] loss: 8760.8574
# [iteration 0900] loss: 8816.4678
# [iteration 0950] loss: 8809.3916
# [iteration 1000] loss: 8770.8555
# [iteration 1050] loss: 8758.3223
# [iteration 1100] loss: 8767.0234
# [iteration 1150] loss: 8770.2305
# [iteration 1200] loss: 8807.5791
# [iteration 1250] loss: 8783.1807
# [iteration 1300] loss: 8756.4316
# [iteration 1350] loss: 8758.4424
# ...

# %%
weight_keys = [key for key in preds.keys() if key.startswith("weight")]

n_keys = len(weight_keys)
n_cols = 3
n_rows = (n_keys + n_cols - 1) // n_cols

fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))
axs = axs.flatten()  

for i, key in enumerate(weight_keys):
    mean_val = preds[key].mean().item()
    axs[i].hist(preds[key].squeeze().detach().numpy(), bins=50)
    key_title = key.replace("weights_", "").replace("weight_", "")
    axs[i].hist(preds[key].squeeze().detach().numpy(), bins=50)
    axs[i].set_title(f"{key_title} (mean={mean_val:.2f})") 



for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

sns.despine()
plt.tight_layout()
plt.show()

# %%
predictive = Predictive(tracts_model, guide=guide, num_samples=1)

with MultiWorldCounterfactual() as mwc:
    with do(actions={"limit": (torch.tensor(1.0), torch.tensor(0.0))}):
        samples = predictive(**subset_for_preds)

print(samples["limit"].shape)
print(samples["housing_units"].shape)

value = samples["limit"]
outcome = samples["housing_units"]

with mwc:
    observed_limit = gather(value, IndexSet(**{"limit": {0}}), event_dims=0)
    low_limit = gather(value, IndexSet(**{"limit": {1}}), event_dims=0)
    high_limit = gather(value, IndexSet(**{"limit": {2}}), event_dims=0)

    observed_units = gather(outcome, IndexSet(**{"limit": {0}}), event_dims=0)
    low_units = gather(outcome, IndexSet(**{"limit": {1}}), event_dims=0)
    high_units = gather(outcome, IndexSet(**{"limit": {2}}), event_dims=0)



fig, axes = plt.subplots(3, 1, figsize=(15, 5))

# Plot the histograms
axes[0].hist(observed_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="observed")
axes[0].set_title("Observed units")
axes[0].legend()
axes[0].set_xlim(-4, 4)

axes[1].hist(low_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="low")
axes[1].set_title("Low units")
axes[1].legend()
axes[1].set_xlim(-4, 4)

axes[2].hist(high_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="high")
axes[2].set_title("High units")
axes[2].legend()
axes[2].set_xlim(-4, 4)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# torch.Size([1, 3, 1, 1, 1, 816])
# torch.Size([1, 3, 1, 1, 1, 816])

# %%
print(tr_do.trace.nodes["limit"]["value"].shape)

assert tr_do.trace.nodes["limit"]["value"].shape == torch.Size([3, 1, 1, 1, 816])


value = tr_do.trace.nodes["limit"]["value"]
outcome = tr_do.trace.nodes["housing_units"]["value"]

with mwc:
    observed_limit = gather(value, IndexSet(**{"limit": {0}}), event_dims=0)
    low_limit = gather(value, IndexSet(**{"limit": {1}}), event_dims=0)
    high_limit = gather(value, IndexSet(**{"limit": {2}}), event_dims=0)

    observed_units = gather(outcome, IndexSet(**{"limit": {0}}), event_dims=0)
    low_units = gather(outcome, IndexSet(**{"limit": {1}}), event_dims=0)
    high_units = gather(outcome, IndexSet(**{"limit": {2}}), event_dims=0)


fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the histograms
axes[0].hist(observed_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="observed")
axes[0].set_title("Observed units")
axes[0].legend()

axes[1].hist(low_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="low")
axes[1].set_title("Low nits")
axes[1].legend()

axes[2].hist(high_units.squeeze().detach().numpy(), bins=50, alpha=0.5, label="high")
axes[2].set_title("High units")
axes[2].legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# prior_predictive_check


prior_predictive = Predictive(tracts_model, num_samples=num_samples)

prior_samples = prior_predictive(**subset_for_preds)

samples_outcome = prior_samples["housing_units"]
pred_means = samples_outcome.mean(axis=0)
pred_low = samples_outcome.quantile(0.05, axis=0)
pred_high = samples_outcome.quantile(0.95, axis=0)


prior_df = pd.DataFrame(
    {
        "housing_units": subset['continuous']["housing_units"],
        "pred_means": pred_means,
        "pred_low": pred_low,
        "pred_high": pred_high,
    }
)

# sort priod_df by housing_units
prior_df = prior_df.sort_values(by="housing_units")


plt.plot(prior_df["housing_units"], prior_df["pred_means"], label="Predictive Mean")
plt.fill_between(
    prior_df["housing_units"],
    prior_df["pred_low"],
    prior_df["pred_high"],
    alpha=0.5,
    label="90% CI",
)
plt.xlabel("Observed Housing Units")
plt.ylabel("Predicted Housing Units")
plt.title("Prior Predictive Check")
plt.legend()
plt.show()

# %%
num_samples = 1000
predictive = Predictive(
    model=tracts_model, guide=guide, num_samples=num_samples, parallel=True
)

with MultiWorldCounterfactual() as mwc:
    with do(actions={"limit": (torch.tensor(1.0), torch.tensor(0.0))}):
        samples = predictive(**subset_for_preds)

print(samples["limit"].shape)
print(samples["housing_units"].shape)

assert samples["limit"].shape == torch.Size([num_samples, 3, 1, 1, 1, 816])
assert samples["housing_units"].shape == torch.Size([num_samples, 3, 1, 1, 1, 816])

value = samples["housing_units"].squeeze()
limit_value = samples["limit"].squeeze()

full = value[:, 1, :]
full_means = full.mean(axis=0)
none = value[:, 2, :]
none_means = none.mean(axis=0)
plt.scatter(x=none, y=full, alpha=0.5, s=4)
plt.plot([-4, 8], [-4, 8], color="red", linestyle="--")
plt.show()

print(full.shape, none.shape)

plt.hist(samples['weight_continuous_limit_housing_units'].numpy())
plt.show()
# Out:
# torch.Size([1000, 3, 1, 1, 1, 816])
# torch.Size([1000, 3, 1, 1, 1, 816])
# torch.Size([1000, 816]) torch.Size([1000, 816])

# %%
with mwc:

    factual_limit= gather(
        samples["limit"], IndexSet(**{"limit": {0}}), event_dims=0
    )
    full_limit = gather(
        samples["limit"], IndexSet(**{"limit": {1}}), event_dims=0
    )

    no_limit = gather(
        samples["limit"], IndexSet(**{"limit": {2}}), event_dims=0
    )

    factual_housing_units = gather(
        samples["housing_units"], IndexSet(**{"limit": {0}}), event_dims=0
    )

    full_housing_units = gather(
        samples["housing_units"], IndexSet(**{"limit": {1}}), event_dims=0
    )

    no_housing_units = gather(
        samples["housing_units"], IndexSet(**{"limit": {2}}), event_dims=0
    )



plt.hist(full_housing_units.flatten(), label = "full_limit", color="blue", alpha=0.5)
plt.hist(no_housing_units.flatten(), color="grey", alpha=0.5, label="no limit")
plt.legend()
plt.show()

# %%
factual_housing_units_means = factual_housing_units.mean(axis=0).flatten().detach()
factual_housing_units_low = (
    factual_housing_units.quantile(0.05, axis=0).flatten().detach()
)
factual_housing_units_high = (
    factual_housing_units.quantile(0.95, axis=0).flatten().detach()
)

full_housing_units_means = (
    full_housing_units.mean(axis=0).flatten().detach()
)
full_housing_units_low = (
    full_housing_units.quantile(0.05, axis=0).flatten().detach()
)
full_housing_units_high = (
    full_housing_units.quantile(0.95, axis=0).flatten().detach()
)

no_housing_units_means = no_housing_units.mean(axis=0).flatten().detach()
no_housing_units_low = no_housing_units.quantile(0.05, axis=0).flatten().detach()
no_housing_units_high = no_housing_units.quantile(0.95, axis=0).flatten().detach()

# TODO consider a different outcome distro
#plt.hist(data['continuous']['housing_units'], alpha=0.5, label="data", bins = 50)
plt.hist(factual_housing_units_means, alpha=0.5, label="factual", bins = 50)
plt.hist(full_housing_units_means, alpha=0.5, label="full", bins = 50)
plt.hist(no_housing_units_means, alpha=0.5, label="no", bins = 50)
plt.legend()
plt.show()

# %%
# Slightly offset years for scatter plot
years = data["categorical"]["year"].flatten().detach().numpy()
years_full = years - 0.1
years_no = years + 0.1


# Scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(
    x=years_full,
    y=full_housing_units_means,
    s=5,
    alpha=0.5,
    label="full",
)
plt.scatter(
    x=years_no,
    y=no_housing_units_means,
    s=5,
    alpha=0.5,
    label="no",
)
plt.legend()

# Boxplot data preparation
data_combined = np.concatenate((factual_housing_units_means, full_housing_units_means))
years_combined = np.concatenate((years, years))
labels_combined = np.concatenate((np.repeat("full", len(years)), np.repeat("no", len(years))))

# Boxplot
sns.boxplot(
    x=years_combined,
    y=data_combined,
    hue=labels_combined,
    dodge=True,
    palette="Set2"
)

for year, full, no in zip(years, full_housing_units_means, no_housing_units_means):
    plt.plot([year - 0.1, year + 0.1], [full, no], color='grey', linestyle='-', linewidth=1.5, alpha=0.5)


# Final adjustments
sns.despine()
plt.title('Full limit and no limit housing units over years')
plt.xlabel('year')
plt.ylabel('housing units')
plt.show()

# %%
year = (subset["categorical"]["year"]).numpy()

def destandardize_housing_units(column):
    mean = ct_dataset_read.standardization_dictionary["housing_units"]["mean"]
    std = ct_dataset_read.standardization_dictionary["housing_units"]["std"]

    return (column * std + mean).round()


destandardized_df = pd.DataFrame(
    {
        "year": year,
        "factual": destandardize_housing_units(
            factual_housing_units_means
        ),
        "full": destandardize_housing_units(full_housing_units_means),
        "no": destandardize_housing_units(no_housing_units_means),
    }
)

destandardized_df.shape

destandardized_by_year = destandardized_df.groupby("year").sum().reset_index()


plt.plot(destandardized_by_year["year"], destandardized_by_year["factual"], label="factual")
plt.plot(destandardized_by_year["year"], destandardized_by_year["full"], label="full")
plt.plot(destandardized_by_year["year"], destandardized_by_year["no"], label="no")
plt.legend()
sns.despine()
plt.show()
